# %%
from pathlib import Path
import os


project_root = Path.cwd()
while project_root.name != 'open-cv-flow' and project_root != project_root.parent:
    project_root = project_root.parent
os.chdir(str(project_root))
print(Path.cwd())
# Out:
# F:\git_hub\open-cv-flow

# %%
from src.features.face_detection import FaceDetection
from matplotlib import pyplot as plt

file_path = project_root / 'tests' / 'images' / 'image.png'
print('file_path : ', file_path)
face_detector = FaceDetection(file_path)
face_detector.detect_faces_cv2()

for face in face_detector.faces:
    x, y, w, h = face.position
    cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

for face in face_detector.faces:
    print(face.name, face.position)
# Out:
# file_path :  F:\git_hub\open-cv-flow\tests\images\image.png
# 얼굴-0001 [467 216  60  60]
# 얼굴-0002 [89 89 82 82]
# 얼굴-0003 [260  89  91  91]
# 얼굴-0004 [352  54  96  96]
# 얼굴-0005 [477  58  88  88]
# 얼굴-0006 [165  57  87  87]

# %%
for face in face_detector.faces:
    x, y, w, h = face.position
    cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

for face in face_detector.faces:
    print(face.name, face.position)

# %%
from src.features.face_detection import FaceDetection
# ----- 얼굴 검출 -----
fd = FaceDetection(str(file_path))
fd.detect_faces_cv2()

# 이미지를 RGB로 변환 후 출력 (OpenCV는 BGR, matplotlib은 RGB)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("Blocked Faces")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       4 fd.detect_faces_cv2()
#       6 # 이미지를 RGB로 변환 후 출력 (OpenCV는 BGR, matplotlib은 RGB)
# ----> 7 plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#       8 plt.axis('off')
#       9 plt.title("Blocked Faces")
#
# NameError: name 'plt' is not defined
